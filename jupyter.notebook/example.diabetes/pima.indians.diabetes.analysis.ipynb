# %% [markdown]
# # Foundations of Data Science Project - Diabetes Analysis
#
# ---------------
# ## Context
# ---------------
#
# Diabetes is one of the most frequent diseases worldwide and the number of diabetic patients are growing over the years. The main cause of diabetes remains unknown, yet scientists believe that both genetic factors and environmental lifestyle play a major role in diabetes.
#
# A few years ago research was done on a tribe in America which is called the Pima tribe (also known as the Pima Indians). In this tribe, it was found that the ladies are prone to diabetes very early. Several constraints were placed on the selection of these instances from a larger database. In particular, all patients were females at least 21 years old of Pima Indian heritage.
#
# -----------------
# ## Objective
# -----------------
#
# Here, we are analyzing different aspects of Diabetes in the Pima Indians tribe by doing Exploratory Data Analysis.
#
# -------------------------
# ## Data Dictionary
# -------------------------
#
# The dataset has the following information:
#
# * Pregnancies: Number of times pregnant
# * Glucose: Plasma glucose concentration over 2 hours in an oral glucose tolerance test
# * BloodPressure: Diastolic blood pressure (mm Hg)
# * SkinThickness: Triceps skin fold thickness (mm)
# * Insulin: 2-Hour serum insulin (mu U/ml)
# * BMI: Body mass index (weight in kg/(height in m)^2)
# * DiabetesPedigreeFunction: A function that scores the likelihood of diabetes based on family history.
# * Age: Age in years
# * Outcome: Class variable (0: a person is not diabetic or 1: a person is diabetic)

# %% [markdown]
# ## Q 1: Import the necessary libraries and briefly explain the use of each library (3 Marks)

# %%
# Remove _____ & write the appropriate library name

import numpy as np

import pandas as pd

import seaborn as sns

import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 1:
#
# - NumPy (imported as np) is used for performing numerical computations in Python. It provides support for large, multi-dimensional arrays and matrices, along with a vast library of mathematical functions to operate on these arrays-
# - Pandas (imported as pd) is used for data manipulation and analysis. It provides data structures for efficiently storing and manipulating large datasets, along with functions for filtering, sorting, and summarizing data-
# - Seaborn (imported as sns) is a data visualization library that is built on top of Matplotlib. It provides a high-level interface for creating informative and attractive statistical graphics, such as scatterplots, histograms, and heatmaps-
# - Matplotlib.pyplot (imported as plt) is a plotting library for Python. It provides functions for creating a wide range of static, animated, and interactive visualizations, including line plots, scatterplots, bar plots, and pie charts. It is the foundation of many other data visualization libraries, including Seaborn.

# %% [markdown]
# ## Q 2: Read the given dataset (2 Marks)

# %%
# Remove _____ & write the appropriate function name

pima = pd.read_csv("diabetes.csv")

# %% [markdown]
# ## Q3. Show the last 10 records of the dataset. How many columns are there? (2 Marks)

# %%
# Remove ______ and write the appropriate number in the function
num_cols = pima.shape[1]
print("Number of columns in the Pima dataset: ", num_cols)

pima.tail(10)
# Out:
# Number of columns in the Pima dataset:  9
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 758            1      106             76             20       79  37.5
# 759            6      190             92             20       79  35.5
# 760            2       88             58             26       16  28.4
# 761            9      170             74             31       79  44.0
# 762            9       89             62             20       79  22.5
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27       79  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60             20       79  30.1
# 767            1       93             70             31       79  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 758                     0.197   26        0
# 759                     0.278   66        1
# ...

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 3:
#
# - pima.shape[1] and pima.tail(10) commands let us to get results.

# %% [markdown]
# ## Q4. Show the first 10 records of the dataset (2 Marks)

# %%
# Remove _____ & write the appropriate function name and the number of rows to get in the output

pima.head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin        BMI  \
# 0            6      148             72             35       79  33.600000
# 1            1       85             66             29       79  26.600000
# 2            8      183             64             20       79  23.300000
# 3            1       89             66             23       94  28.100000
# 4            0      137             40             35      168  43.100000
# 5            5      116             74             20       79  25.600000
# 6            3       78             50             32       88  31.000000
# 7           10      115             69             20       79  35.300000
# 8            2      197             70             45      543  30.500000
# 9            8      125             96             20       79  31.992578
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# ...

# %% [markdown]
# ## Q5. What do you understand by the dimension of the dataset? Find the dimension of the `pima` dataframe. (3 Marks)

# %%
# Remove _____ & write the appropriate function name

pima.shape
# Out:
# (768, 9)

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 5:
#
# - In data analysis, the dimension of a dataset refers to the number of rows and columns in the dataset. The number of rows represents the number of observations or samples in the dataset, while the number of columns represents the number of features or variables in the dataset.
# - pima.shape gives the result.

# %% [markdown]
# ## Q6. What do you understand by the size of the dataset? Find the size of the `pima` dataframe. (3 Marks)

# %%
# Remove _____ & write the appropriate function name

pima.size
# Out:
# 6912

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 6:
#
# - The size of a dataset refers to the amount of data it contains. This can be measured in various ways, such as the number of rows, the number of columns, or the total number of elements in the dataset.
# - pima.size gives the result.

# %% [markdown]
# ## Q7. What are the data types of all the variables in the data set? (2 Marks)
# **Hint: Use the info() function to get all the information about the dataset.**

# %%
# Remove _____ & write the appropriate function name
pima.info()
pima.dtypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# ...

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 7:
#
# - pima.info() gives the result.
# - pima.dtypes gives the result.

# %% [markdown]
# ## Q8. What do we mean by missing values? Are there any missing values in the `pima` dataframe? (4 Marks)

# %%
# Remove _____ & write the appropriate function name

pima.isnull().values.any()
pima.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 8:
#
# - In a dataset, missing values refer to the absence of a value in a particular data point. These missing values could be due to a variety of reasons, such as data entry errors, non-response in surveys, or data corruption.
# - pima.isnull().values.any() or pima.isnull().sum() can be used.

# %% [markdown]
# ## Q9. What do the summary statistics of the data represent? Find the summary statistics for all variables except 'Outcome' in the `pima` data. Take one column/variable from the output table and explain all its statistical measures. (5 Marks)

# %%
# Remove _____ & write the appropriate function name

print(pima.iloc[: , 0 : 8].dropna())
print(pima.drop('Outcome', axis=1).describe())
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35       79  33.6
# 1              1       85             66             29       79  26.6
# 2              8      183             64             20       79  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27       79  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60             20       79  30.1
# 767            1       93             70             31       79  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# ...

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 9:
#
# - Summary statistics provide a way to summarize the main characteristics of a dataset in a concise and meaningful way. These statistics include measures such as mean, median, mode, standard deviation, minimum and maximum values, and quartiles, among others.
# - print(pima.iloc[: , 0 : 8].dropna()) or print(pima.drop('Outcome', axis=1).describe()) can be used.

# %% [markdown]
# ## Q 10. Plot the distribution plot for the variable 'BloodPressure'. Write detailed observations from the plot. (2 Marks)

# %%
# Remove _____ & write the appropriate library name

sns.displot(pima['BloodPressure'], kind = 'kde')

plt.show()

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 10:
#
# - sns.displot(pima['BloodPressure'], kind = 'kde') can be used.
# - Detailed observations from the plot:
#   - The distribution of 'BloodPressure' is roughly bell-shaped and symmetric, indicating that the values are distributed relatively evenly around the mean value.
#   - The peak of the distribution is around 70-80 mmHg, which is the most common value for 'BloodPressure' in the dataset.
#   - The distribution has a long tail on the right side, indicating that there are some values of 'BloodPressure' that are much higher than the mean value.
#   - There are no negative values for 'BloodPressure', indicating that the values are all physically meaningful.

# %% [markdown]
# ## Q 11. What is the 'BMI' of the person having the highest 'Glucose'? (2 Marks)

# %%
# Remove _____ & write the appropriate function name

# pima[pima['Glucose'] == pima['Glucose'].idxmax()]['BMI']

max_glucose_idx = pima['Glucose'].idxmax()
bmi_for_max_glucose = pima.loc[max_glucose_idx, 'BMI']
print("BMI for person with highest Glucose: ", bmi_for_max_glucose)
# Out:
# BMI for person with highest Glucose:  42.9

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 11:

# %% [markdown]
# ## Q12.
# ### 12.1 What is the mean of the variable 'BMI'?
# ### 12.2 What is the median of the variable 'BMI'?
# ### 12.3 What is the mode of the variable 'BMI'?
# ### 12.4 Are the three measures of central tendency equal?
#
# ### (4 Marks)

# %%
# Remove _____ & write the appropriate function name

m1 = pima['BMI'].mean()  # mean
print('mean:', m1)

m2 = pima['BMI'].median()  # median
print('median:', m2)

m3 = pima['BMI'].mode()[0]  # mode
print('mode:', m3)
# Out:
# mean: 32.45080515543617
# median: 32.0
# mode: 32.0

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 12:
#
# - This code will calculate the mean, median, and mode of the 'BMI' variable and print the results to the console.
#   - The mean BMI is the average value of the 'BMI' variable, and represents the central value of the distribution if the distribution is roughly symmetric.
#   - The median BMI is the middle value of the 'BMI' variable when the values are sorted in ascending or descending order. It represents the central value of the distribution if the distribution is skewed or has extreme values.
#   - The mode BMI is the most frequent value of the 'BMI' variable in the dataset. It represents the most typical value of the variable in the dataset.
# - It is rare for the mean, median, and mode to be exactly equal, especially in datasets that are not perfectly symmetric. In this case, it is possible that the mean, median, and mode are different. You can check whether the three measures of central tendency are equal by comparing their values.
# - Thus they are almost equal but not exactly same.

# %% [markdown]
# ## Q13. How many women's 'Glucose' levels are above the mean level of 'Glucose'? (2 Marks)

# %%
# Remove _____ & write the appropriate function name

# print(pima[pima['Glucose'] > pima['Glucose'].mean()].shape[0])

# Calculate mean glucose level for women
mean_glucose_women = pima.loc[pima['Outcome'] == 0, 'Glucose'].mean()

# Count number of women with glucose levels above mean
women_above_mean = pima.loc[(pima['Outcome'] == 0) & (pima['Glucose'] > mean_glucose_women), 'Glucose'].count()

print("Number of women with glucose levels above mean: ", women_above_mean)
# Out:
# Number of women with glucose levels above mean:  227

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 13:
#
# - The answer is showen above.

# %% [markdown]
# ## Q14. How many women have their 'BloodPressure' equal to the median of 'BloodPressure' and their 'BMI' less than the median of 'BMI'? (2 Marks)

# %%
# Remove _____ & write the appropriate column name

#pima[(pima['BloodPressure'] == pima['BloodPressure']._____) & (pima['BMI'] < pima['BMI']._____)]

print('Result:', len(pima[(pima['Outcome'] == 0) & (pima['BloodPressure'] == pima['BloodPressure'].median()) & (pima['BMI'] < pima['BMI'].median())]))
# Out:
# Result: 16

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 14:

# %% [markdown]
# ## Q15. Create a pairplot for the variables 'Glucose', 'SkinThickness', and 'DiabetesPedigreeFunction'. Write your observations from the plot. (3 Marks)

# %%
# Remove _____ & write the appropriate function name

sns.pairplot(data = pima, vars = ['Glucose', 'SkinThickness', 'DiabetesPedigreeFunction'], hue = 'Outcome')
plt.show()

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 15:
#
# - Observations from the pairplot:
#   - The distribution of 'Glucose' seems to be positively skewed, with a long tail on the right side.
#   - There appears to be a positive linear correlation between 'Glucose' and 'SkinThickness'.
#   - The scatterplot of 'DiabetesPedigreeFunction' vs. 'SkinThickness' shows a somewhat scattered pattern with no clear correlation.
#   - The diagonal subplots show the distribution of each variable, with 'DiabetesPedigreeFunction' being highly right-skewed.

# %% [markdown]
# ## Q16. Plot the scatterplot between 'Glucose' and 'Insulin'. Write your observations from the plot. (4 Marks)

# %%
# Remove _____ & write the appropriate function name

sns.scatterplot(x = 'Glucose', y = 'Insulin', data = pima)
plt.show()

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 16:
#
# - Observations from the scatterplot:
#   - There seems to be a positive linear correlation between 'Glucose' and 'Insulin'.
#   - However, there are several points with very high insulin levels despite having normal glucose levels, which may be outliers or require further investigation.
#   - There are also several points with zero insulin levels, which could either be true or missing values.
#   - Overall, the scatterplot suggests a moderate positive association between the two variables, but with some variability and potential outliers.

# %% [markdown]
# ## Q 17. Plot the boxplot for the 'Age' variable. Are there outliers? (2 Marks)

# %%
# Remove _____ & write the appropriate function and column name 

plt.boxplot(pima['Age'])

plt.title('Boxplot of Age')
plt.ylabel('Age')
plt.show()

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 17:
#
# - Observations from the boxplot:
#   - There are several outliers on the higher end of the distribution, beyond the upper whisker of the boxplot.
#   - These outliers suggest that there are some women in the dataset who are significantly older than the rest of the population.
#   - The median of the distribution (represented by the line inside the box) is around 30-35 years old, with the interquartile range (IQR) between approximately 25-45 years old.

# %% [markdown]
# ## Q18. Plot histograms for the 'Age' variable to understand the number of women in different age groups given whether they have diabetes or not. Explain both histograms and compare them. (5 Marks)

# %%
# Remove _____ & write the appropriate function and column name

plt.hist(pima[pima['Outcome'] == 1]['Age'], bins = 5)
plt.title('Distribution of Age for Women who has Diabetes')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
# Remove _____ & write the appropriate function and column name

plt.hist(pima[pima['Outcome'] == 0]['Age'], bins = 5)
plt.title('Distribution of Age for Women who do not have Diabetes')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 18:
#
# - The x-axis shows the age groups, and the y-axis shows the frequency (number of women) in each group. The alpha parameter controls the transparency of each histogram, and the label parameter adds a label to each histogram. The xlabel, ylabel, and title functions add labels to the plot, and the legend function adds a legend to distinguish between the two histograms.
# - By comparing the two histograms, we can see that the distribution of age is similar for women with and without diabetes. Both histograms are roughly symmetric and have a peak in the middle. However, the histogram for women with diabetes is shifted slightly to the right, indicating that on average, women with diabetes are older than women without diabetes. Additionally, both histograms have a tail to the right, indicating that there are some women in the dataset who are older than the majority of the population.

# %% [markdown]
# ## Q 19. What is the Interquartile Range of all the variables? Why is this used? Which plot visualizes the same? (5 Marks)

# %%
# Remove _____ & write the appropriate variable name

Q1 = pima.quantile(0.25)
Q3 = pima.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# Pregnancies                  5.0000
# Glucose                     40.5000
# BloodPressure               16.0000
# SkinThickness               12.0000
# Insulin                     48.2500
# BMI                          9.1000
# DiabetesPedigreeFunction     0.3825
# Age                         17.0000
# Outcome                      1.0000
# dtype: float64

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 19:
#
# - Inter Quartile Range (IQR) is the difference between the third quartile (Q3) and the first quartile (Q1) of a variable. It represents the spread or variability of the middle 50% of the data.
# - IQR is used as a measure of variability or dispersion of a variable, particularly in non-normal distributions. It is less sensitive to outliers than range or standard deviation, making it a more robust measure of spread in such cases.
# - Box plots visualize the IQR, where the box represents the middle 50% of the data (between Q1 and Q3), the median is shown as a line inside the box, and the whiskers extend to the smallest and largest observations within 1.5 times the IQR from the box. Points outside the whiskers are considered outliers.

# %% [markdown]
# ## Q 20. Find and visualize the correlation matrix. Write your observations from the plot. (3 Marks)

# %%
# Remove _____ & write the appropriate function name and run the code

corr_matrix = pima.iloc[ : ,0 : 8].corr()

corr_matrix
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.128022       0.208987       0.009393
# Glucose                      0.128022  1.000000       0.219765       0.158060
# BloodPressure                0.208987  0.219765       1.000000       0.130403
# SkinThickness                0.009393  0.158060       0.130403       1.000000
# Insulin                     -0.018780  0.396137       0.010492       0.245410
# BMI                          0.021546  0.231464       0.281222       0.532552
# DiabetesPedigreeFunction    -0.033523  0.137158       0.000471       0.157196
# Age                          0.544341  0.266673       0.326791       0.020582
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.018780  0.021546                 -0.033523
# Glucose                   0.396137  0.231464                  0.137158
# ...

# %%
# Remove _____ & write the appropriate function name

plt.figure(figsize = (8, 8))
sns.heatmap(corr_matrix, annot = True)

# Display the plot
plt.show()

# %% [markdown]
# #### Write your Answer here:

# %% [raw]
# Ans 20:
#
# - Observations:
#   - The correlation matrix shows the pairwise correlations between all variables in the dataset.
#   - The highest positive correlation is observed between 'Age' and 'Pregnancies'.
#   - 'Glucose' has a moderately positive correlation with 'Insulin' and 'SkinThickness'.
#   - 'BMI' has a moderately positive correlation with 'SkinThickness' and 'Insulin'.
#   - 'DiabetesPedigreeFunction' has a weak positive correlation with 'Age' and 'BMI'.
#   - There is a weak negative correlation between 'BloodPressure' and 'SkinThickness'.
